# %%
import qrcode

# Replace with your actual GitHub Pages link
url = "https://vibeswithjay.github.io/grandfather-slideshow/"

img = qrcode.make(url)
img.save("slideshow_qr.png")

print("✅ QR code saved as slideshow_qr.png")
# Out:
# ✅ QR code saved as slideshow_qr.png
